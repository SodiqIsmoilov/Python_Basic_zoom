# %%
#Case 1
n = int(input('son <1-7> : '))
if n==1:
    print('Dushanba')
elif n==2:
    print('Seshanba')
elif n==3:
    print('Chorshanba')
elif n==4:
    print('Payshanba')
elif n==5:
    print('Juma')
elif n==6:
    print('Shanba')
elif n==7:
    print('Yanshanba')
# Out:
# son <1-7> : 5
# Juma

# %%
#Case 2
k = int(input('K son <1-5> : '))
if k==1:
    print('Yomon')
elif k==2:
    print('Qoniqarsiz')
elif k==3:
    print('Qoniqarli')
elif k==4:
    print('Yaxshi')
elif k==5:
    print('A`lo')
else:
    print('Xato')
# Out:
# K son <1-5> : 6
# Xato

# %%
#Case 3
n = int(input('Oy raqami <0-11>: '))
if n==0:
    print(n+1, '-oy, qish')
elif n==1:
    print(n+1, '-oy, qish')
elif n==2:
    print(n+1, '-oy, bahor')
elif n==3:
    print(n+1, '-oy, bahor')
elif n==4:
    print(n+1, '-oy, bahor')
elif n==5:
    print(n+1, '-oy, yoz')
elif n==6:
    print(n+1, '-oy, yoz')
elif n==7:
    print(n+1, '-oy, yoz')
elif n==8:
    print(n+1, '-oy, kuz')
elif n==9:
    print(n+1, '-oy, kuz')
elif n==10:
    print(n+1, '-oy, kuz')
elif n==11:
    print(n+1, '-oy, qish')
# Out:
# Oy raqami : 3
# 4 -oy, bahor

# %%
#Case 4
n = int(input('Oy raqami <0-11> : '))
if n==0 or n==2 or n==4 or n==6 or n==7 or n==9 or n==11:
    print('Bu oyda 31 kun bor')
elif n==3 or n==5 or n==8 or n==10:
    print('Bu oyda 30 kun bor')
elif n==1:
    print('Bu oyda 28 kun bor')
# Out:
# Oy raqami <0-11> : 6
# Bu oyda 31 kun bor

# %%
#Case 5
a=int(input('a son '))
b=int(input('b son '))
amal = int(input('amal kiriting '))
if amal==1:
    print(a + b)
elif amal==2:
    print(a - b)
elif amal==3:
    print(a / b)
elif amal==4:
    print(a * b)
# Out:
# a son 2
# b son 3
# amal kiriting 4
# 6

# %%
#Case 6
n = int(input('Uzunlik birlik <1-5> : '))
m = int(input('Uzunlik : '))
if n==1:
    print(m/10, 'm')
elif n==2:
    print(1000*m, 'm')
elif n==3:
    print(m, 'm')
elif n==4:
    print(m/1000, 'm')
elif n==5:
    print(m/100, 'm')
# Out:
# Uzunlik birlik <1-5> : 1
# Uzunlik : 260
# 26.0 m

# %%
#Case 7
n = int(input('Og`irlik birlik <1-5> : '))
m = int(input('Og`irlik : '))
if n==1:
    print(m, 'kg')
elif n==2:
    print(m/10**6, 'kg')
elif n==3:
    print(m/10**3, 'kg')
elif n==4:
    print(m*10**3, 'kg')
elif n==5:
    print(m*100, 'kg')

# %%
#Case 8
d = int(input('kun '))
m = int(input('oy '))
if (m==5 or m==7 or m==10 or m==12) and d==1:
    print(30,'/',m-1)
elif (m==4 or m==6 or m==9 or m==11 or m==2) and d==1:
    print(31,'/',m-1)
elif m==8 and d==1:
    print(31,'/',m-1)
elif m==1 and d==1:
    print(31,'/', 12)
elif m==3 and d==1:
    print(28,'/',m-1)
else:
    print(d-1,'/',m)
# Out:
# kun 1
# oy 10
# 30 /1 9

# %%
#Case 9
d = int(input('kun '))
m = int(input('oy '))
if (m==4 or m==6 or m==9 or m==11) and d==30:
    print(1,'/',m+1)
elif (m==1 or m==3 or m==5 or m==8 or m==10) and d==31:
    print(1,'/',m+1)
elif m==7 and d==31:
    print(1,'/',m+1)
elif m==12 and d==31:
    print(1,'/',1)
elif m==2 and d==28:
    print(1,'/',m+1)
else:
    print(d+1,'/',m)
# Out:
# kun 30
# oy 9
# 1 / 10

# %%
#Case 10

# %%
#Case 11

# %%
#Case 12
pi=3.14
elem = int(input('Doira ementlari '))
if elem==1:
    r = int(input('Radius '))
    print('Diametr', 2*r,'Doira uzunligi', 2*pi*r,'Doira yuzi', pi*r**2)
elif elem==2:
    d=int(input('Diametr'))
    print('Radius', d/2,'Doira uzunligi',pi*d,'Doira yuzi', pi*((d**2)/4))
elif elem==3:
    l=int(input('Doira uzunligi '))
    print('Radius', l/(2*pi), 'Diametr', l/pi,'Doira yuzi', (l**2)/(4*pi))
elif elem==4:
    s=int(input('Doira yuzi'))
    print('Radius', (s/pi)**(1/2), 'Diametr', (4*s/pi)**(1/2), 'Doira uzunligi', (4*pi*s)**(1/2) )
# Out:
# Doira ementlari 1
# Radius 5
# Diametr 10 Doira uzunligi 31.400000000000002 Doira yuzi 78.5

# %%
#Case 13
from math import *
elem = int(input('Uchberchak elementlari '))
if elem==1:
    a = int(input('Katet '))
    print('Gipotenuza', a*sqrt(2), 'Gipatenuzaga tushirilgan balandlik', a/sqrt(2), 'Yuza', (a**2)/2)
elif elem==2:
    c = int(input('Gipatenuza '))
    print('Katet', c/sqrt(2),'Gipatenuzaga tushirilgan balandlik', c/2, 'Yuza', (c**2)/4 )
elif elem==3:
    h = int(input('Gipatenuzaga tushirilgan balandlik '))
    print('Katet', h*sqrt(2),'Gipatenuza',2*h,'Yuza',h**2)
elif elem==4:
    s=int(input('Yuza '))
    print('Katet', sqrt(2*s), 'Gipatenuzaga tushirilgan balandlik',sqrt(4*s), 'Gipatenuza', (c**2)/8)
# Out:
# Uchberchak elementlari 1
# Katet 4
# Gipotenuza 5.656854249492381 Gipatenuzaga tushirilgan balandlik 2.82842712474619 Yuza 8.0

# %%
#Case 14
elem = int(input("Element raqmi(1-tomon, 2-ichki aylana R1, 3-tashqi aylana R2, 4-yuza):"))
if elem==1:
    a=int(input("Tomonni kiriting:"))    
    print("Ichki radus:", a*3**0.5/6)
    print("Tashqi radius:", a*3**0.5/3)
    print("Yuza:", a**2*3**0.5/4)
if elem==2:
    r=int(input("Ichki radiusni kiriting:"))
    print("Tomon:", (6*r)/3**0.5)    
    print("Tashqi radius:", 2*r)
    print("Yuza:", 3*3**0.5*r**2)
if elem==3:
    R=int(input("Tashqi radiusni kiriting:"))
    print("Tomon:", (3*R)/3**0.5)
    print("Ichki radius:", R/2)    
    print("Yuza:", (3*3**0.5*R**2)/2)
if elem==4:
    S=int(input("Yuzani kiriting:"))
    print("Tomon:", 2*(S/3**0.5)**0.5)
    print("Ichki radius:", (S/(3*3**0.5))**0.5)
    print("Tashqi radius:", ((2*S)/(3*3**0.5))**0.5)

# %%
#Case 15
n=int(input('N <6-14> '))
m=int(input('M <1-4> '))
result = ''
if n==6:
    result=result + 'olti '
if n==7:
    result=result + 'yetti '
if n==8:
    result=result + 'sakki '
if n==9:
    result = result + 'to`qqiz '
if n==10:
    result = result + 'o`n '
if n==11:
    result = result + 'valet '
if n==12:
    result = result + 'dama '
if n==13:
    result = result + 'qirol '
if n==14:
    result = result + 'tuz '
if m==1:
    result = result + 'g`isht'
if m==2:
    result = result + 'olma'
if m==3:
    result = result + 'chillak'
if m==4:
    result = result + 'qarg`a'
print(result)
# Out:
# N <6-14> 6
# M <1-4> 4
# olti qarg`a

# %%
#Case 16
y = int(input("Yoshingiz <20-69>:"))
bir = y%10
on = y//10
if 20<=y<=69:
    if on == 2:
        print('Yigirma', end='')
    if on == 3:
        print('O`ttiz', end='')
    if on == 4:
        print('Qirq', end='')
    if on == 5:
        print('Ellik', end='')
    if on == 6:
        print('Oltmish', end='')
    if bir == 1:
        print(' bir', end='')
    if bir == 2:
        print(' ikki', end='')
    if bir == 3:
        print(' uch', end='')
    if bir == 4:
        print(' to`rt', end='')
    if bir == 5:
        print(' besh', end='')
    if bir == 6:
        print(' olti', end='')
    if bir == 7:
        print(' yetti', end='')
    if bir == 8:
        print(' sakkiz', end='')
    if bir == 9:
        print(' to`qqiz', end='')
else:
    print('Yosh oraliqdan chiqib kettingiz')
# Out:
# Yoshingiz <20-69>:22
# Yigirma ikki

# %%
#Case 17
m = int(input("Masala <10-40>:"))
bir = m % 10
on = m // 10
if 10<=m<=40:
    if on==1:
        print('O`n',end='')
    if on==2:
        print('Yigirma',end='')
    if on==3:
        print('O`ttiz',end='')
    if on==4:
        print('Qirq',end='')
    if bir == 1:
        print(' bir', end='ta')
    if bir == 2:
        print(' ikki', end='ta')
    if bir == 3:
        print(' uch', end='ta')
    if bir == 4:
        print(' to`rt', end='ta')
    if bir == 5:
        print(' besh', end='ta')
    if bir == 6:
        print(' olti', end='ta')
    if bir == 7:
        print(' yetti', end='ta')
    if bir == 8:
        print(' sakkiz', end='ta')
    if bir == 9:
        print(' to`qqiz', end='ta')
    print(' masala')
else:
    print('Berilgan oraliqdan chiqish xatosi yuz berdi')
# Out:
# Masala <10-40>:99
# Berilgan oraliqdan chiqish xatosi yuz berdi

# %%
#Case 18
n = int(input('son kiriting<100-999> :'))
bir = n % 10
on = n % 100 // 10
yuz = n // 100
if yuz == 1:
    print(' bir', end=' ')
if yuz == 2:
    print(' ikki', end=' ')
if yuz == 3:
    print(' uch', end=' ')
if yuz == 4:
    print(' to`rt', end=' ')
if yuz == 5:
    print(' besh', end=' ')
if yuz == 6:
    print(' olti', end=' ')
if yuz == 7:
    print(' yetti', end=' ')
if yuz == 8:
    print(' sakkiz', end=' ')
if yuz == 9:
    print(' to`qqiz', end=' ')
if yuz:
    print('yuz', end=' ')
if on == 1:
    print('o`n', end=' ')
if on == 2:
    print('yigirma', end=' ')
if on == 3:
    print('o`tiz', end=' ')
if on == 4:
    print('qirq', end=' ')
if on == 5:
    print('ellik', end=' ')
if on == 6:
    print('olmish', end=' ')
if on == 7:
    print('yetmish', end=' ')
if on == 8:
    print('sakson', end=' ')
if on == 9:
    print('to`qson', end='')
if bir == 1:
    print(' bir')
if bir == 2:
    print(' ikki')
if bir == 3:
    print(' uch')
if bir == 4:
    print(' to`rt')
if bir == 5:
    print(' besh')
if bir == 6:
    print(' olti')
if bir == 7:
    print(' yetti')
if bir == 8:
    print(' sakkiz')
if bir == 9:
    print(' to`qqiz')
# Out:
# son kiriting<100-999> :100
#  bir yuz

# %%
#Case 19
yil = int(input("Yil kiriting <1984-yildan>:"))
farq = yil-1984
rang = farq % 5 + 1
hayvon = farq % 12 + 1
if rang==1:
    rang="Yashil"
elif rang==2:
    rang="Qizil"
elif rang==3:
    rang="Sariq"
elif rang==4:
    rang="Oq"
elif rang==5:
    rang="Qora"
if hayvon==1:
    hayvon="sichqon"
elif hayvon==2:
    hayvon="sigir"
elif hayvon==3:
    hayvon="yo'lbars"
elif hayvon==4:
    hayvon="quyon"
elif hayvon==5:
    hayvon="ajdar"
elif hayvon==6:
    hayvon="ilon"
elif hayvon==7:
    hayvon="ot"
elif hayvon==8:
    hayvon="qo'y"
elif hayvon==9:
    hayvon="maymun"
elif hayvon==10:
    hayvon="tovuq"
elif hayvon==11:
    hayvon="it"
elif hayvon==12:
    hayvon="to'ng'iz"
print(rang, hayvon, "yili")
# Out:
# Yil kiriting(1984-yildan keyingi):1996
# Sariq sichqon yili

# %%
#Case 20
D = int(input("Kun:"))
M = int(input("Oy: "))
if M==1 or M==3 or M==5 or M==7 or M==8 or M==10 or M==12:
    D=31
elif M==2:
    D=28
elif M==4 or M==6 or M==9 or M==11:
    D=30
else:
    print("Bunday oy yoki kun yo'q")
if D>=20 and M==1 or D<=18 and M==2:
    print("Qovg'a")
elif D>=19 and M==2 or D<=20 and M==3:
    print("Baliq")
elif D>=21 and M==3 or D<=19 and M==4:
    print("Qo'y")
elif D>=20 and M==4 or D<=20 and M==5:
    print("Buzoq")
elif D>=21 and M==5 or D<=21 and M==6:
    print("Egizaklar")
elif D>=22 and M==6 or D<=22 and M==7:
    print("Qisqichbaqa")
elif D>=23 and M==7 or D<=22 and M==8:
    print("Arslon")
elif D>=23 and M==8 or D<=22 and M==9:
    print("Parizod")
elif D>=23 and M==9 or D<=22 and M==10:
    print("Tarozi")
elif D>=23 and M==10 or D<=22 and M==11:
    print("Chayon")
elif D>=23 and M==11 or D<=21 and M==12:
    print("O'qotar")
elif D>=22 and M==12 or D<=19 and M==1:
    print("Echki")

# %%
#if JUNIOR Masala
n= int(input('son '))
answer = ''
if n//10==1:
    answer = answer + 'o`n'
if n//10==2:
    answer = answer + 'yigirma'
if n//10==3:
    answer = answer + 'o`ttiz'
if n//10==4:
    answer = answer + 'qirq'
if n//10==5:
    answer = answer + 'qirq'
if n//10==6:
    answer = answer + 'oltmish'
if n//10==7:
    answer = answer + 'yetmish'
if n//10==8:
    answer = answer + 'sakson'
if n//10==9:
    answer = answer + 'to`qson'
if n%10==1:
    answer = answer + ' bir'
if n%10==2:
    answer = answer + ' ikki'
if n%10==3:
    answer = answer + ' uch'
if n%10==4:
    answer = answer + ' to`rt'
if n%10==5:
    answer = answer + ' besh'
if n%10==6:
    answer = answer + ' olti'
if n%10==7:
    answer = answer + ' yetti'
if n%10==8:
    answer = answer + ' sakkiz'
if n%10==9:
    answer = answer + ' to`qqiz'
if n==0:
    answer = answer + 'nol'
print(answer)
# Out:
# son 88
# sakson sakkiz
