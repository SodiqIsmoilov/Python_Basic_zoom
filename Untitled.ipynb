# %%
#MinMax - 4
N = int(input('N='))
i = 1
p = 1
minum = int(input('n='))
while i<N:
    i+=1
    n = int(input('n='))
    if minum>n:
        minum = n
        p = i              
print(p)
# Out:
# N=10
# n=12
# n=99
# n=81
# n=-54
# n=-91
# n=1
# n=0
# n=16
# n=45
# n=-13
# 5

# %%
#MinMax - 5
N = int(input('N = '))
i = 1
m = float(input('m = '))
v = float(input('v = '))
p = m/v
while i<N:    
    m = float(input('m = '))
    v = float(input('v = '))
    if p<m/v:
        p = m/v
    i+=1
print('Eng katta zichlik =',p)
# Out:
# N = 5
# m = 2.5
# v = 1
# m = 3
# v = 2
# m = 6
# v = 6
# m = 9
# v = 12
# m = 8
# v = 2
# Eng katta zichlik = 4.0

# %%
#MinMax - 6
