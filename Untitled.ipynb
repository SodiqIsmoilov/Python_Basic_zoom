# %%
#MinMax - 1
N = int(input('N='))
i = 1
katta = kichik = int(input('n ='))
while i<N:
    n = int(input('n='))
    if n>katta:
        katta = n
    if n<kichik:
        kichik = n
    i+=1
print('Max =',katta,'Min =', kichik)
# Out:
# N=3
# n =2
# n=2
# n=2
# Max = 2 Min = 2

# %%
#MinMax - 2
N = int(input('N='))
i = 1
a = float(input('a ='))
b = float(input('b ='))
s = a*b
while i<N:
    a = float(input('a ='))
    b = float(input('b ='))
    if s>a*b:
        s = a*b
    i+=1
print('Eng kichik yuza =', s/2)
# Out:
# N=5
# a =3
# b =2
# a =6
# b =1
# a =4
# b =4
# a =2
# b =4
# a =3
# b =3
# Eng kichik yuza = 3.0

# %%
#MinMax - 3
from math import sqrt
N = int(input('N='))
i = 1
a = float(input('a ='))
b = float(input('b ='))
p = a+b+sqrt(pow(a,2)+pow(b,2))
while i<N:
    a = float(input('a ='))
    b = float(input('b ='))
    if p<a+b+sqrt(pow(a,2)+pow(b,2)):
        p = a+b+sqrt(pow(a,2)+pow(b,2))
    i+=1
print('Eng katta perimetr =', p)
# Out:
# N=3
# a =3
# b =4
# a =5
# b =2
# a =6
# b =1
# Eng kichik yuza = 13.082762530298218

# %%
#MinMax - 4
N = int(input('N='))
i = 1
p = 1
minum = int(input('n='))
while i<N:
    i+=1
    n = int(input('n='))
    if minum>n:
        minum = n
        p = i              
print(p)
# Out:
# N=10
# n=12
# n=99
# n=81
# n=-54
# n=-91
# n=1
# n=0
# n=16
# n=45
# n=-13
# 5

# %%
#MinMax - 5
N = int(input('N = '))
i = 1
m = float(input('m = '))
v = float(input('v = '))
p = m/v
while i<N:    
    m = float(input('m = '))
    v = float(input('v = '))
    if p<m/v:
        p = m/v
    i+=1
print('Eng katta zichlik =',p)
# Out:
# N = 5
# m = 2.5
# v = 1
# m = 3
# v = 2
# m = 6
# v = 6
# m = 9
# v = 12
# m = 8
# v = 2
# Eng katta zichlik = 4.0

# %%
#MinMax - 6
N = int(input('N='))
i = 1
mn = 1
mx = 1
maxim = minum = int(input('n='))
while i<N:
    i+=1
    n = int(input('n='))
    if minum>n:
        minum = n
        mn = i
    if maxim<n:
        maxim = n
        mx = i
print(mx, mn)
# Out:
# N=10
# n=5
# n=3
# n=2
# n=1
# n=0
# n=5
# n=0
# n=6
# n=6
# n=5
# 8 5

# %%
#MinMax - 7
N = int(input('N='))
i = 1
mn = 1
mx = 1
maxim = minum = int(input('n='))
while i<N:
    i+=1
    n = int(input('n='))
    if minum>n:
        minum = n
        mn = i
    if maxim<n:
        maxim = n
        mx = i
print(mx, mn)

# %%
#MinMax - 8
N = int(input('N='))
i = 1
x = True
while i<=N:
    n = int(input('n='))
    if x:
        minum = n
        j,k = i,i
        x = False
    if minum>n:
        minum = n
        k = i
    if minum==n:
        minum=n
        j = i
    i+=1
print(k,j)
# Out:
# N=3
# n=1
# n=2
# n=2
# 1 1

# %%
#MinMax - 10
N = int(input('N='))
i = 1
x = True
while i<=N:
    n = int(input('n='))
    if x:
        minum, maxim = n,n
        j ,k = i , i
        x = False
    if n>maxim:
        maxim = n
        j = i
    if n<minum:
        minum = n
        k = i
    i+=1
if k>j:
    print(j)
else:
    print(k)
# Out:
# N=4
# n=4
# n=4
# n=4
# n=5
# 1

# %%
#MinMax - 12
N = int(input('N='))
i = 1
x = True
while i<=N:
    n = int(input('n='))
    if n>0 and x:
        minum = n        
        x = False   
    
    if n<minum and n>0:
        minum = n    

    i+=1

if x:
    print(0)
else:
    print(minum)
# Out:
# N=3
# n=3
# n=-5
# n=1
# 1

# %%
#MinMax - 15
b = int(input('B='))
c = int(input('C='))
i = 1
x = True
while i<=10:
    n = int(input('n='))
    if c>n>b and x:
        maxim = n 
        k = i
        x = False   
    
    if n>maxim and c>n>b:
        maxim = n   
        k = i
    i+=1
print(k)
# Out:
# B=2
# C=5
# n=3
# n=4
# n=2
# n=15
# n=100
# n=6
# n=5
# n=8
# n=18
# n=9
# 2

# %%
#MinMax - 17
N = int(input('N='))
i = 1
x = True
while i<=N:
    n = int(input('n='))
    if x:
        maxim= n        
        x = False   
    
    if n>maxim:
        maxim = n 
    
    if maxim <= n:
        k = i
    i+=1
print(N-k)
# Out:
# N=5
# n=3
# n=21
# n=4
# n=2
# n=1
# 3

# %%
# MinMax 30
N = int(input('N='))
i = 1
x = True
s = 0
p = 0
while i<=N:
    n = int(input('n='))
    if x:
        maxim = n
        x = False
    if maxim<n:
        maxim = n

    if maxim == n:       
        y = True        
    else:
        y = False
        
    if y:
        s +=1
    else:
        p = s
        s = 0
    # Maksimal takrorlanganlarning minimalini topamiz
    if s == 0:
        print('p=',p)
        
    i+=1
# Out:
# N=12
# n=8
# n=8
# n=8
# n=8
# n=1
# p= 4
# n=8
# n=8
# n=8
# n=1
# p= 3
# n=8
# n=8
# n=8
