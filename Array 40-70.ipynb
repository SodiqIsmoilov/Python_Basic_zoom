# %%
from random import randint

# %%
#Array 41
n = int(input('n='))
A = [randint(1,10) for i in range(n)]
print(A)
maxim = A[0]+A[1]
j = 0
for i in range(len(A)-1):   
    if A[i]+A[i+1]>maxim:
        maxim = A[i]+A[i+1]
        j = i
print(A[j], A[j+1])
# Out:
# n=10
# [9, 2, 8, 10, 9, 8, 4, 5, 6, 10]
# 10 9

# %%
#Array 42
n = int(input('n='))
R = int(input('R='))
A = [randint(1,10) for i in range(n)]
print(A)
minum_R=[]
for i in range(len(A)-1):
    minum_R.append(abs(A[i]+A[i+1] - R))
min_index = minum_R.index(min(minum_R))

print(A[min_index], A[min_index+1])
# Out:
# n=10
# R=12
# [5, 4, 6, 8, 2, 4, 1, 1, 2, 7]
# 4 6

# %%
#Array 43
n = int(input('n='))
A = [randint(1,10) for i in range(n)]
print(A)
A.sort()
print(A)
s = 1
for i in range(1,len(A)):
    if A[i-1]!=A[i]:
        s+=1
print(s)
# Out:
# n=10
# [4, 1, 10, 10, 7, 8, 1, 8, 9, 3]
# [1, 1, 3, 4, 7, 8, 8, 9, 10, 10]
# 7

# %%
#Array 44
A = [1,5,3,8,4,5,9,7]
for i in range(n-1):
    for j in range(i+1,n):
        if A[i] == A[j]:
            print(i,j)
            break
# Out:
# 1 5

# %%
#Array 45
n = int(input('n='))
A = [randint(1,10) for i in range(n)]
print(A)
minum = abs( A[0]-A[1] )
javob = 0
for i in range(1,len(A)-1):
    if abs(A[i]-A[i+1]) < minum:
        minum = abs(A[i]-A[i+1])
        javob = i
    if minum==0:
        break        
print(javob,javob+1)
# Out:
# n=10
# [9, 1, 6, 1, 8, 1, 1, 7, 4, 8]
# 5 6

# %%
#Array 46
n = int(input('n='))
R = int(input('R='))
A = [randint(1,10) for i in range(n)]
print(A)

x = False
minum = abs(A[0]+A[1] - R)
for i in range(len(A)):    
    for j in range(i+1, len(A)):
        k = abs(A[i]+A[j] - R)
        if k<minum:
            minum = k
            a, b = A[i], A[j]
            x = True
if x:
    print(a,b)
else:
    print(A[0],A[1])
# Out:
# n=10
# R=21
# [4, 7, 6, 10, 2, 6, 9, 8, 9, 5]
# 10 9

# %%
#Array 47
n = int(input('n='))
A = [randint(1,10) for i in range(n)]
print(A)
javob = [A[0]]
for i in range(1,n):
    for j in range(i+1,n-1):
        if A[i] != A[j]:
            javob.append(A[i])
# Out:
# n=10
# [8, 1, 6, 8, 9, 9, 4, 10, 6, 8]

# %%
#Array 48
n = int(input('n='))
A = [randint(1,10) for i in range(n)]
print(A)
maxi =A.count(A[0])
elem = A[0]
for i in range(1,n):
    c = A.count(A[i])    
    if maxi <c:
        maxi = c
        elem = A[i]
print(maxi,elem)
# Out:
# n=20
# [2, 8, 3, 7, 1, 10, 9, 7, 2, 6, 1, 8, 7, 2, 2, 1, 1, 2, 8, 2]
# 6 2

# %%
#Array 49
n = int(input('n='))
A = [randint(-5,20) for i in range(n)]
print(A)
for i in range(n):
    if A[i]<1 or A[i]>n:
        print(i)
        break
else:
    print(0)
# Out:
# n=10
# [6, 1, 18, 8, 17, -1, 19, -4, 17, 10]
# 2

# %%
#Array 50
n = int(input('n='))
A = [randint(1,10) for i in range(n)]
print(A)
s = 0
for i in range(n-1):
    if A[i]>A[i-1]:
        s+=1
print(s)
# Out:
# n=10
# [6, 1, 4, 3, 7, 6, 7, 1, 1, 1]
# 4

# %%
#Array 51
a = [1,2,3,4,5]
b = [6,7,8,9,10]
for i in range(len(a)):
    a[i],b[i] = b[i],a[i]
print(a,b)
# Out:
# [6, 7, 8, 9, 10] [1, 2, 3, 4, 5]

# %%
#Array 51 v2.0
a = [1,2,3,4,5]
b = [6,7,8,9,10]
a,b = b,a
print(a,b)
# Out:
# [6, 7, 8, 9, 10] [1, 2, 3, 4, 5]

# %%
#Array 52
n = int(input('n='))
A = [randint(1,10) for i in range(n)]
print(A)
B = []
for i in range(n):
    if A[i]<5:
        B.append(A[i])
    else:
        B.append(A[i]/2)
print(B)
# Out:
# n=10
# [3, 3, 9, 8, 2, 3, 9, 4, 2, 3]
# [3, 3, 4.5, 4.0, 2, 3, 4.5, 4, 2, 3]

# %%
#Array 53
n = int(input('n='))
A = [randint(1,10) for i in range(n)]
B = [randint(1,10) for i in range(n)]
print(A)
print(B)
C = []
for i in range(n):
    C.append(max(A[i],B[i]))
print(C)
# Out:
# n=10
# [8, 6, 3, 5, 5, 1, 8, 2, 8, 8]
# [9, 1, 7, 2, 8, 7, 6, 8, 2, 4]
# [9, 6, 7, 5, 8, 7, 8, 8, 8, 8]

# %%
#Array 54
n = int(input('n='))
A = [randint(1,10) for i in range(n)]
print(A)
B = []
for i in range(n):
    if A[i]%2==0:
        B.append(A[i])
print(B, len(B))
# Out:
# n=10
# [10, 9, 6, 4, 10, 7, 7, 2, 7, 1]
# [10, 6, 4, 10, 2] 5

# %%
#Array 55
n = int(input('n='))
A = [randint(1,10) for i in range(n)]
print(A)
B=[]
for i in range(1,n,2):
    B.append(A[i])
print(B)
# Out:
# n=13
# [7, 1, 5, 9, 2, 8, 3, 6, 4, 1, 8, 1, 9]
# [1, 9, 8, 6, 1, 1]

# %%
#Array 56
n = int(input('n='))
A = [randint(1,10) for i in range(n)]
print(A)
B=[]
# B.extend(A[::2])
# B.extend(A[1::2])
B = A[::2] + A[1::2]
print(B)
# Out:
# n=10
# [2, 6, 7, 2, 4, 2, 6, 10, 1, 3]
# [2, 7, 4, 6, 1, 6, 2, 2, 10, 3]

# %%
#Array 57
n = int(input('n='))
A = [randint(1,10) for i in range(n)]
print(A)
B = []
for i in range(0,len(A),2):
    B.append(A[i])
for i in range(1,len(A),2):
    B.append(A[i])
print(B)
# Out:
# n=10
# [9, 7, 10, 1, 4, 5, 9, 9, 8, 4]
# [9, 10, 4, 9, 8, 7, 1, 5, 9, 4]

# %%
#Array 57 v2.0
n = int(input('n='))
A = [randint(1,10) for i in range(n)]
print(A)
B = A[::2] + A[1::2]
print(B)
# Out:
# n=10
# [2, 3, 10, 8, 10, 3, 5, 7, 6, 6]
# [2, 10, 10, 5, 6, 3, 8, 3, 7, 6]

# %%
#Array 58
n = int(input('n='))
A = [randint(1,10) for i in range(n)]
print(A)
B=[A[0]]
for i in range(2,n+1):
    B.append(sum(A[:i]))
print(B)
# Out:
# n=10
# [1, 6, 4, 2, 8, 5, 5, 8, 4, 9]
# [1, 7, 11, 13, 21, 26, 31, 39, 43, 52]

# %%
#Array 59
n = int(input('n='))
A = [randint(1,10) for i in range(n)]
print(A)
B = [A[0]]
for i in range(1,n):
    x = sum(A[0:i])
    B.append(x/i)
print(B)
# Out:
# n=10
# [10, 1, 7, 8, 4, 4, 4, 10, 1, 8]
# [10, 10.0, 5.5, 6.0, 6.5, 6.0, 5.666666666666667, 5.428571428571429, 6.0, 5.444444444444445]

# %%
#Array 60
n = int(input('n='))
A = [randint(1,10) for i in range(n)]
print(A)
B = []
for i in range(n):
    x = sum(A[i:])
    B.append(x)
print(B)
# Out:
# n=5
# [1, 3, 8, 9, 1]
# [22, 21, 18, 10, 1]

# %%
#Array 61
n = int(input('n='))
A = [randint(1,10) for i in range(n)]
print(A)
B = [sum(A)/len(A)]
for i in range(1,n):
    x = sum(A[i:])
    B.append(x/(n-i))
print(B)
# Out:
# n=3
# [1, 4, 1]
# [2.0, 2.5, 1.0]

# %%
#Array 62
n = int(input('n='))
A = [randint(-10,10) for i in range(n)]
print(A)
B,C=[],[]
for i in range(n):
    if A[i]>0:
        B.append(A[i])
    elif A[i]<0:
        C.append(A[i])
print('B massiv elementlari soni=', len(B), B)
print('C massiv elementlari soni=', len(C), C)
# Out:
# n=20
# [9, 5, -1, 4, -1, -3, 3, -8, -2, 9, 2, -9, 5, -3, 5, -6, 5, 6, 5, 10]
# B massiv elementlari soni= 12 [9, 5, 4, 3, 9, 2, 5, 5, 5, 6, 5, 10]
# C massiv elementlari soni= 8 [-1, -1, -3, -8, -2, -9, -3, -6]

# %%
#Array 63
# n = int(input('n='))
A = [randint(-10,10) for i in range(5)]
B = [randint(-10,10) for i in range(5)]
print(A); print(B)
C = A+B
for i in range(10):
    for j in range(i+1,10):
        if C[i]>C[j]:
            C[i], C[j] = C[j],C[i]
print(C)
# Out:
# [10, -6, 9, -10, -10]
# [-8, -2, 4, -2, 3]
# [-10, -10, -8, -6, -2, -2, 3, 4, 9, 10]

# %%
#Array 64
n = int(input('n='))
A = [randint(-5,5) for i in range(n)]
B = [randint(-10,10) for i in range(n)]
C = [randint(-20,20) for i in range(n)]
D = A+B+C
count = 0
for i in range(len(D)):
    for j in range(i+1,len(D)-1):
        if D[i]>D[j+1]:
            D[i], D[j+1] = D[j+1],D[i]
            count+=1
print(D)
print(count)
# Out:
# n=10
# [-20, -19, -17, -12, -9, -9, -6, -5, -4, -4, -3, -2, -2, -2, -1, -1, 0, 0, 2, 3, 3, 3, 5, 5, 6, 9, 9, 12, 11, 16]
# 142

# %%
#Array 65
n = int(input('n='))
A = [randint(-5,5) for i in range(n)]
print(A)
k = int(input('k='))
if k<n-1:
    x = A[k]
    for i in range(n):
        A[i] +=x
    print(A)
else:
    print('n dan kichik son kiriting !!!')
# Out:
# n=10
# [2, -1, 3, 0, 2, -3, 1, -2, -4, -4]
# k=10
# n dan kichik son kiriting !!!

# %%
del A
del k

# %%
#Array 66
# yuqoridagi A massivni delete qilish kerak!!
n = int(input('n='))
A = [randint(1,10) for i in range(n)]
print(A)
x = True
for i in range(n):
    if A[i]%2==0 and x:
        k = A[i]
        x = False
    if not(x) and A[i]%2==0:
        A[i] +=k
print(A)
# Out:
# n=5
# [6, 1, 3, 4, 5]
# [12, 1, 3, 10, 5]

# %%
del A
del k

# %%
#Array 67
n = int(input('n='))
A = [randint(1,10) for i in range(n)]
print(A)
A.reverse()
x = True
for i in range(n):
    if A[i]%2==1 and x:
        k = A[i]
        x = False
        A.reverse()
    if not(x) and A[i]%2==1:        
        A[i] +=k
print(A)
# Out:
# n=5
# [8, 10, 5, 3, 10]
# 3 3 [8, 10, 8, 6, 10]

# %%
del A
del k

# %%
#Array 68
n = int(input('n='))
A = [randint(1,10) for i in range(n)]
print(A)
mini = min(A)
maxi = max(A)
for i in range(n):
    if A[i]==mini:
        A[i]=maxi
    elif A[i] ==maxi:
        A[i]=mini
print(A)
# Out:
# n=20
# [1, 6, 9, 3, 5, 7, 9, 7, 6, 9, 8, 2, 4, 7, 2, 9, 7, 4, 8, 2]
# [9, 6, 1, 3, 5, 7, 1, 7, 6, 1, 8, 2, 4, 7, 2, 1, 7, 4, 8, 2]

# %%
#Array 69
n = int(input('n='))
A = [randint(1,10) for i in range(n)]
print(A)
if n%2==0:
    for i in range(0,n,2):
        A[i], A[i+1] = A[i+1],A[i]
    print(A)
else:
    print('n soniga juft son kiriting!!!')
# Out:
# n=11
# [2, 8, 4, 5, 7, 5, 6, 10, 1, 10, 9]
# n soniga juft son kiriting!!!

# %%
#Array 70
n = int(input('n='))
A = [randint(1,10) for i in range(n)]
print(A)
A =+ A[:n//2]
print()
print(A[n//2:])
# Out:
# n=10
# [6, 1, 3, 2, 9, 9, 10, 7, 3, 8]
# [6, 1, 3, 2, 9]
# [9, 10, 7, 3, 8]
