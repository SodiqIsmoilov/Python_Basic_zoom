# %%
#  8
from math import sqrt
n = int(input('n='))
count = 0
for i in range(1,n+1):
    for j in range(1,n+1):        
        k=int(sqrt(pow(i,2)+pow(j,2)))
    print(k)
# Out:
# n=10
# 10
# 10
# 10
# 10
# 11
# 11
# 12
# 12
# 13
# 14

# %%
n = int(input('n soni : '))
s = 1
f = 1
for i in range(2,n+1):
    f*=i
    s*=(1+1/f)**2
print(s)

# %%
#while 1
a = float(input('a = '))
b = float(input('b = '))
while a>b:
    a-=b
print(round(a,2))
# Out:
# a = 8.6
# b = 3
# 2.6

# %%
#while 2
a = float(input('a = '))
b = float(input('b = '))
son = 0
while a>b:
    a-=b
    son+=1
print(son)
# Out:
# a = 8.6
# b = 3
# 2

# %%
#while 3
n = float(input('n = '))
k = float(input('k = '))
butun = 0
while n>k:
    n-=k
    butun+=1
print('Butun qismi=',butun,'Qoldiq =', round(n,2))
# Out:
# n = 5.3
# k = 3
# Butun qismi= 1 Qoldiq = 2.3

# %%
#while 4
n = int(input('n = '))
while n>2:
    n-=3
print(n)
if n==0:
    print('3 ning darajsi')
else:
    print('Emas !')
# Out:
# n = 5
# 2
# Emas !

# %%
#while 5    v1.0
n = int(input('n = '))
k=0
while n!=2**k:
    k+=1
print(k)
# Out:
# n = 1024
# 10

# %%
#while 6
n = int(input('n soni : '))
f = 1
while n>1:
    f*=n
    n-=2
print(f)
# Out:
# n soni : 5
# 15

# %%
#while 7
n = int(input('n soni : '))
k=0
while n>=k**2:    
    k+=1
print(k)
# Out:
# n soni:50
# 8

# %%
#while 8
n = int(input('n soni : '))
k=0
while k**2 <= n:    
    k+=1
print(k-1)
# Out:
# n soni : 50
# 7

# %%
#while 9    n>1
n = int(input('n soni : '))
k=0
while n>=3**k:    
    k+=1
print(k)
# Out:
# n soni : 100
# 5

# %%
#while 10
n = int(input('n soni : '))
k=0
while n>=3**k:    
    k+=1
print(k-1)
# Out:
# n soni : 100
# 4

# %%
#while 11
n = int(input('n soni : '))
k = 1
s = 0
while s<=n:
    s+=k
    k+=1
print(k, 'summa', s)
# Out:
# n soni : 55
# 12 summa 66

# %%
#while 12
n = int(input('n soni : '))
k = 1
s = 0
while n>=s+k:
    s+=k
    k+=1
print(k, 'summa', s)
# Out:
# n soni : 55
# 11 summa 55

# %%
#while 13
n = int(input('n soni : '))
k = 1
s = 0
while n>=s+1/k:
    s+=1/k
    k+=1    
print(k-1, 'summa ', s)
# Out:
# n soni : 2
# 3 summa  1.8333333333333333

# %%
#while 14
n = int(input('n soni : '))
k = 0
s = 0
while n>=s:
    k+=1
    s+=1/k     
print(k-1, 'summa ', s)
# Out:
# n soni : 3
# 10 summa  3.0198773448773446

# %%
#while 15
s = float(input('s='))
p = float(input('p='))
a = s
oy = 0
while 2*a>s:
    s += (s*p/100)
    oy+=1
print(oy,s)
# Out:
# s=100
# p=20
# 4 207.36

# %%
#while 16
p = int(input('p='))
s = 10
kun = 1
while s<200:
    s += (s*(1+p/100))
    kun+=1
print('Kun=',kun,'Masofa=',int(s))
# Out:
# p=50
# Kun= 5 Masofa= 390

# %%
#while 17
n = int(input('n='))
m = int(input('m='))
butun = 0
while n>m:
    n-=m
    butun+=1
print('butun qism=',butun,'qoldiq=',n)
# Out:
# n=11
# m=2
# butun qism= 5 qoldiq= 1

# %%
#while 18
n = int(input('n='))
while n!=0:
    print(n%10,end='')
    n //=10
# Out:
# n=01
# 1

# %%
#while 19
n = int(input('n='))
s=0
soni = 0
while n!=0:
    s+=(n%10)
    soni+=1
    n //=10
print('Raqamlar yo`gindisi=',s, 'Raqamlar soni=', soni)
# Out:
# n=1000
# Raqamlar yo`gindisi= 1 Raqamlar soni= 4

# %%
#while 20
n = int(input('n='))
soni = 0
while n!=0:
    if n%10==2:
        soni+=1
    n //=10
print('2 lar soni ', soni,'ta')
# Out:
# n=101
# 2 lar soni  0 ta

# %%
#while 21
n = int(input('n='))
javob = False
while n!=0:
    if n%2==1:
        javob = True
    if javob:
        break
    n //=10
print(javob)
# Out:
# n=84
# False

# %%
#while 22
n = int(input('n='))
javob = True
i = 2
c = 0    # count 
while i<int(n/2)+1 and javob:
    if n%i==0:
        javob = False
        print(i)
    i+=1
    c+=1
print(javob, c)
# Out:
# n=2135468455
# 5
# False 4

# %%
#while 23   EKUB(a,b)   (oddiy)
a = int(input('a='))
b = int(input('b='))
i = 0
count = 0
while i<a or i<b:
    i+=1
    if a%i != 0 and b%i !=0:
        continue
    if a%i == 0 and b%i ==0:
        ekub=i
    
    count+=1
print(ekub,count)
# Out:
# a=300
# b=270
# 30 26

# %%
#while 23   EKUB(a,b)   (optimal)
a = int(input('a='))   
b = int(input('b='))
if b>a:
    a,b = b,a
c = 0    # count
while b!=0:
    c+=1
    a%=b
    a,b = b,a
print(a,c)
# Out:
# a=1024
# b=1624
# 8 7

# %%
#while 24    v1.0
n = int(input('n='))
f1=1
f2=1
javob = False
while f2<n:
    f = f2 + f1
    f1 = f2
    f2 = f
    if f == n:
        javob = True
if javob:
    print(javob)
else:
    print(javob)
# Out:
# n=34
# True

# %%
#while 24  v2.0
n = int(input('n='))
f1=1
f2=1
javob = False
while f2<n:
    f2 = f2 + f1
    f1 = f2 - f1
    if f2 == n:
        javob = True
if not(javob):
    print(javob)
else:
    print(javob)
# Out:
# n=12
# False

# %%
#while 25
n = int(input('n='))
f1=1
f2=1
while f2<=n:
    f2 = f2 + f1
    f1 = f2 - f1      
print(f2)
# Out:
# n=22
# 34

# %%
#while 26
n = int(input('n='))
f1=1
f2=1
while f2<=n:
    f2 = f2 + f1
    f1 = f2 - f1
print('Oldingisi',f1,'Keyingisi',f2)
# Out:
# n=21
# Oldingisi 21 Keyingisi 34

# %%
#while 27
n = int(input('n='))
f1=1
f2=1
hadi = 1
while f2<=n:
    f2 = f2 + f1
    f1 = f2 - f1
    hadi+=1
print(hadi)
# Out:
# n=13
# 7

# %%
#while 28
e = float(input('e='))
a = 2
k = 0
while True:
    ak = 2 + 1/a
    if abs(ak-a)<e:
        print(ak, a)
        break
    a = ak
    k+=1
print(k)
# Out:
# e=0.01
# 2.413793103448276 2.4166666666666665
# 3

# %%
#while 28   
e = float(input('e='))
a = 2
ak=2.5
k=1
while abs(ak-a)>e:
    a = ak
    ak = 2 + 1/a    
    k+=1
    print(ak, a)
print('k=',k)
# Out:
# e=0.0001
# 2.4 2.5
# 2.4166666666666665 2.4
# 2.413793103448276 2.4166666666666665
# 2.414285714285714 2.413793103448276
# 2.4142011834319526 2.414285714285714
# k= 6

# %% [markdown]
# # 29 ni tekshirish kerak

# %%
#while 29   
e = float(input('e='))
a1 = 1
a2 = 2
ak = 5/3
while abs(ak-a1)>=e:
    ak = (a1+2*a2)/3
    a1=a2
    
    a2=ak
print(a1,a2)
# Out:
# e=0.01
# 1.7530864197530864 1.748971193415638

# %%
#while 30
a = int(input('A ='))
b = int(input('B ='))
c = int(input('C ='))

k1 = 0
while a>=c:
    a-=c
    k1+=1
print(k1)
k2=0
while b>=c:
    b-=c
    k2+=1
print(k1*k2)
# Out:
# A =6
# B =4
# C =3
# 2
# 2
