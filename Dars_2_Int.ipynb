# %%
#Integer 1
L = int(input("Uzunlikni santimetrda kiriting: "))
m = L // 100
l = L % 100
print(L, " santimetr = ", m, " metr ", l, " santimetrga teng.")

# %%
#Integer 2
M = int(input("Og'irlik kgda: "))
t = M // 1000
k = M % 1000
print(M, " kg = ", t, " t ", k, " kg")

# %%
#Integer 3
B = int(input("Fayl hajmi (baytda): "))
kB = B // 1024
b = B % 1024
print(B, "bayt =", kB, "kB", b, "B.")

# %%
#Integer 4
A = int(input("A = "))
B = int(input("B = "))
C = A // B
print("A da B ", C, "marta joylashdi")

# %%
#Integer 5
A = int(input("A = "))
B = int(input("B = "))
C = A // B
D = A % B
print("A da B ", C, "marta joylashadi", D, "qism qoladi")

# %%
#Integer 6
A = int(input("Ikki xonali son: "))
B = A // 10
C = A % 10
print(B, " ta o'nlik,", C, "ta birlik")

# %%
#Integer 7
A = int(input("Ikki xonali son kiritng : "))
B = A // 10
C = A % 10
D = B+C
print("Raqamlar yig'indisi: ", D)

# %%
#Integer 8
A = int(input("Ikki xonali son: "))
B = A // 10
C = A % 10
D = C * 10 + B
print("Teskarisi : ", D)
# Out:
# Ikki xonali son: 12
# Teskarisi :  21

# %%
#Integer 9
A = int(input("Uch xonali son kiritng : "))
B = A // 100
print("Yuzlik son: ", B)

# %%
#Integer 10
A = int(input("Uch xonali son kiritng: "))
B = A % 10
C = A // 10 % 10
print("Birlik : ", B, " O'nlik : ", C)
# Out:
# Uch xonali son kiritng: 123
# Birlik :  3  O'nlik :  2

# %%
#Integer 11
A = int(input("Uch xonali son kiritng: "))
B = A // 100
C = A // 10 % 10
D = A % 10
result = B + C + D
print("Raqamlar yig'indisi:", result)

# %%
#Integer 12
A = int(input("Uch xonali son kiritng: "))
B = A // 100
C = A // 10 % 10
D = A % 10
result = D*100+C*10+B
print("Teskari:", result)

# %%
#Integer 13
A = int(input("Uch xonali son kiritng: "))
B = A // 100
C = A // 10 % 10
D = A % 10
result = C*100 + D*10 + B
print("Teskari son:",result)

# %%
#Integer 14
A = int(input("Uch xonali son kiritng: "))
B = A // 100
C = A // 10 % 10
D = A % 10
E = D*100 + B*10 + C
print("Teskari son:", E)

# %%
#Integer 15
A = int(input("Uch xonali son  kiritng: "))
B = A // 100
C = A // 10 % 10
D = A % 10
result = C*100 + B*10 + D
print("Teskari son:", result)

# %%
#Integer 16
A = int(input("Uch xonali son  kiritng: "))
B = A // 100
C = A // 10 % 10
D = A % 10
result = B*100+D*10+C
print("Teskari son:", result)

# %%
#Integer 17
A = int(input("son(999<) : "))
B = A % 1000 // 100
print("Yuzliklar xonasidagi son:", B)

# %%
#Integer 18
A = int(input("son(999<) : "))
B = A % 10000 // 1000
print("Mingliklar xonasidagi son:", B)

# %%
#Integer 19
N = int(input("Kun boshidan o'tgan sekund: "))
Minut = N // 60
print("Kun boshidan ", Minut, "daqiqa o`tdi.")

# %%
#Integer 20
N = int(input("Kun boshidan o'tgan sekund: "))
Hour = N // 3600
print("Kun boshidan" , Hour , "soat o`tdi:")

# %%
#Integer 21
N = int(input("Kun boshidan o'tgan sekund: "))
M = N // 60
S = N % 60
print("Kun boshidan ", M,  "minut " S" sekund o`tdi.")

# %%
#Integer 22
N = int(input("Kun boshidan o'tgan sekund: "))
Hour = N // 3600
Second = N % 60
print("Kun boshidan ",Hour ," soat ", Second," sekund o`tdi.")

# %%
#Integer 23
N = int(input("Kun boshidan o'tgan sekund: "))
H = N // 3600
M = N % 3600 // 60
S = N % 60
print("Kun boshidan " , H," soat ",M," minut ", S," sekund o`tdi.")

# %%
#Integer 24
Y = int(input("kunni kiriting <1-365> :"))
D = Y % 7
print("kun haftaning ", H," kuniga to'g'ri keladi")

# %%
#Integer 25
Y = int(input("kunni kiriting <1-365> : "))
H = (Y+10) % 7
print("kun haftaning ", H,"kuniga to'g'ri keladi")

# %%
#Integer 26
Y = int(input("kunni kiriting <1-365> : "))
H = Y % 7 + 1
print("kun haftaning ", H," kuniga to`g`ri keladi")

# %%
#Integer 27
Y = int(input("kunni kiriting <1-365> : "))
Day = (Y+12) % 7 + 1
print("kun haftaning ", Day," kuniga to`g`ri keladi")

# %%
#Integer 28
Y = int(input("kunni kiriting <1-365> : "))
N = int(input("1-7 hafta kunni kiriting: "))
D = (Y + N + 5) % 7 + 1
print("kun haftaning ", D, " kuniga to`g`ri keladi")
# print(f"kun haftaning  {H} kuniga to`g`ri keladi") ---> f stringni

# %%
#Integer 29
A = int(input("A = "))
B = int(input("B = "))
C = int(input("C = "))
n = A // C
m = B // C
yuzala_soni = n * m
yuz1 = A%C * A
yuz2 = B%C * (B-B%C)
qoldiq_yuza = yuz1 + yuz2
print(f"Kvadrat soni {yuzala_soni} va joylashmagan qism yuzi {qoldiq_yuza}")

# %%
#Integer 30
Y = int(input("Yilni kiriting: "))
Yuz = Y // 100 + 1
print(f"Siz kiritgan yil {Yuz} yuz yillikka kiradi")

# %%
# Darsdagi qo`shimcha misol
A = int(input("A = "))
B = int(input("B = "))
C = A // B
D = A % B
print(f"A kesmada B kesma {C} marta bor qoldiq  {D}")

# %%
Y = int(input("kunni kiriting <1-365> : "))
W = Y % 7
if W == 1:
    print("Dushanba")
elif W == 2:
    print("Seshanba")
elif W == 3:
    print("Chorshanba")
elif W == 4:
    print("Payshanba")
elif W == 5:
    print("Juma")
elif W == 6:
    print("Shanba")
elif W == 0:
    print("Yakshanba")

# %%
N = int(input("Kun boshidan o'tgan sekund: "))
Y = N // 3600 // 24 // 30 // 360
O = N  // 3600 // 24  % 360 // 30
K = N  // 3600 % 360 % 30 // 24
H = N  // 3600 % 360 % 30 % 24
M = N % 3600 // 60
S = N % 60
print(f"Kun boshidan {Y} yil, {O} oy, {K} kun {H} soat {M} minut {S} sekund o'tdi.")

# %%
N = int(input("Sekund: "))
S = N % 60
M = N % 3600 // 60 
H = N // 3600 % 24
K = N // 3600 // 24 % 30
O = N // 3600 // 24 // 30 % 360 // 12
Y = N // 3600 // 24 // 30 // 360 % 100
A = N // 3600 // 24 // 30 // 360 // 100
print(f" {N} s = {A} asr {Y} yil {O} oy {K} kun {H} soat {M} minut {S} sekund")

# %%
a = int(input("a = "))
print(a<0)

# %%
a = int(input("a = "))
print( a%2 != 0)
