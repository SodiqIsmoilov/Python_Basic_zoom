# %%
#if - 1
n = int(input('son :'))
if n>0:
    n+=1
print(n)
# Out:
# son :0
# 0

# %%
#if - 2
n = int(input('son :'))
if n>0:
    n+=1
else:
    n-=2
print(n)
# Out:
# son :-2
# -4

# %%
#if - 3
n = int(input('son :'))
if n>0:
    n+=1
elif n<0:
    n-=2
else:
    n = 10
print(n)
# Out:
# son :0
# 10

# %%
#if - 4
a = int(input('a son :'))
b = int(input('b son :'))
c = int(input('c son :'))
s = 0
if a>0:
    s+=1
if b>0:
    s+=1
if c>0:
    s+=1
print(s)
# Out:
# a son :2
# b son :3
# c son :6
# 3

# %%
#if - 5
a = int(input('a son :'))
b = int(input('b son :'))
c = int(input('c son :'))
s = 0
if a>0:
    s+=1
if b>0:
    s+=1
if c>0:
    s+=1
print('Musbat ', s, 'Manfiylari ', 3-s)
# Out:
# a son :1
# b son :2
# c son :-3
# Musbat  2 Manfiylari  1

# %%
# if - 6
a = int(input('a son :'))
b = int(input('b son :'))
if a>b:
    print(a)
else:
    print(b)
# Out:
# a son :2
# b son :3
# 3

# %%
# if - 7
a = int(input('a son :'))
b = int(input('b son :'))
if a>b:
    print('1-si katta')
else:
    print('2-si katta')

# %%
#if - 8
a = int(input('a son :'))
b = int(input('b son :'))
if a>b:
    print(a, b)
else:
    print(b, a)

# %%
#if - 9
a = int(input('a son :'))
b = int(input('b son :'))
if a>b:
    a = a + b
    b = a - b
    a = a - b
print(a, b)
# Out:
# a son :6
# b son :3
# 3 6

# %%
# if - 10 
a = int(input('a son :'))
b = int(input('b son :'))
if a == b:
    a = a + b
    b = a
else:
    a = b = 0
print(a, b)
# Out:
# a son :1
# b son :2
# 0 0

# %%
# if - 11
a = int(input('a son :'))
b = int(input('b son :'))
if a == b:
    a = b = 0
elif a>b:
    b = a
else:
    a = b
print(a,b)
# Out:
# a son :3
# b son :2
# 3 3

# %%
#if - 12
a = int(input('a son :'))
b = int(input('b son :'))
c = int(input('c son :'))
if a>=b>=c or b>=a>=c:
    print(c)
elif a>=c>=b or c>=a>=b:
    print(b)
elif b>=c>=a or c>=b>=a:
    print(a)
# Out:
# a son :-1
# b son :0
# c son :3
# -1

# %%
#if - 13
a = int(input('a son :'))
b = int(input('b son :'))
c = int(input('c son :'))
if b<a<c or c<a<b:
    print("O'rtachasi",a)
elif a<b<c or c<b<a:
    print("O'rtachasi",b)
else:  
    print("O'rtachasi",c)
# Out:
# a son :6
# b son :11
# c son :100
# O'rtachasi 11

# %%
#if - 14
a = int(input('a son :'))
b = int(input('b son :'))
c = int(input('c son :'))
if a<b<c:
    print("Min ", a, "Max ", c)
elif a<c<b:
    print("Min ", a, "Max ", b)
elif b<a<c:
    print("Min ", b, "Max ", c)
elif b<c<a:
    print("Min ", b, "Max ", a)
elif c<b<a:
    print("Min ", c, "Max ", a)
elif c<a<b:  
    print("Min ", c, "Max ", b)
else:
    print("sonlar teng kiritildi")
# Out:
# a son :1
# b son :1
# c son :3
# sonlar teng kiritildi

# %%
#if - 15
a = int(input('a son :'))
b = int(input('b son :'))
c = int(input('c son :'))
min = a
if a>b:
    min = b    
    if min>c:
        min=c
        print(a,b)
    print(a,c)
elif min>c:
    min=c
    print(b,c)
# Out:
# a son :1
# b son :2
# c son :3

# %%
#if - 16
a = int(input('a son :'))
b = int(input('b son :'))
c = int(input('c son :'))
if a<b<c:
    a = a * 2
    b = b * 2
    c = c * 2
else:
    a = a * (-1)
    b = b * (-1)
    c = c * (-1)
print(a,b,c)
# Out:
# a son :2
# b son :2
# c son :3
# -2 -2 -3

# %%
#if 17
a = int(input('a son :'))
b = int(input('b son :'))
c = int(input('c son :'))
if a>b>c or a<b<c:
    a = a * 2
    b = b * 2
    c = c * 2
else:
    a = a * (-1)
    b = b * (-1)
    c = c * (-1)
print(a,b,c)
# Out:
# a son :-1
# b son :-2
# c son :-3
# -2 -4 -6

# %%
#if 18
a = int(input('a son :'))
b = int(input('b son :'))
c = int(input('c son :'))
if a==b!=c:
    print('3')
elif a==c!=b:
    print('2')
elif b==c!=a:
    print('1')
# Out:
# a son :-1
# b son :-2
# c son :-1
# 2

# %%
#if 19
a = int(input('a son :'))
b = int(input('b son :'))
c = int(input('c son :'))
d = int(input('d son :'))
if a==b==c!=d:
    print("To'rtinchi son teng emas")
elif a==b==d!=c:
    print("Uchinchi son teng emas")
elif a==c==d!=b:
    print("Ikkinchi son teng emas")
elif c==b==d!=a:
    print("Birinchi son teng emas")
else:
    print("Uchta son ham teng yoki teng emas")

# %%
#if 20
a = int(input('a son :'))
b = int(input('b son :'))
c = int(input('c son :'))
if abs(a-b) > abs(a-c):
    print('Eng yaqin masofa',abc(a-c))
elif abs(a-b) < abs(a-c):
    print('Eng yaqin masofa',abs(a-b))
else:
    print('Masofalar teng')
# Out:
# a son :0
# b son :3
# c son :-3
# Masofalar teng

# %%
#if 21
x = int(input('x '))
y = int(input('y '))
if x==0 and y==0:
    print(0)
elif x!=0 and y!=0:
    print(3)
elif x!=0:
    print(1)
elif y!=0:
    print(2)
# Out:
# x -1
# y -2
# 3

# %%
#if 22
x = int(input('x '))
y = int(input('y '))
if x>0 and y>0:
    print('I chorak')
elif x<0 and y>0:
    print('II chorak')
elif x<0 and y<0:
    print('III chorak')
elif x>0 and y<0:
    print('IV chorak')
# Out:
# x 6
# y -2
# IV chorak

# %%
#if 23
x1 = int(input('x1 :'))
y1 = int(input('y1 :'))
x2 = int(input('x2 :'))
y2 = int(input('y2 :'))
x3 = int(input('x3 :'))
y3 = int(input('y3 :'))

if x1==x2 and y2==y3:
    x4=x3
    y4=y1
    print("x4=", x4, "y4=", y4)
else:
    print("Koordinatalar xato kiritildi ")

# %%
#if 24
from math import sin
x = float(input('x :'))
if x>0:
    print(2*sin(x))
else:
    print(x-6)
# Out:
# x :1
# 1.682941969615793

# %%
#if 25
x = float(input('x :'))
if x>2 or x<-2:
    print(2*x)
else:
    print(-3*x)
# Out:
# x :-9
# -18.0

# %%
#if 26

if x<=0:
    print(-x)
elif 0<x<2:
    print(x**2)
elif x>=2:
    print(4)
# Out:
# x :-2
# 2.0

# %%
#if 27
x = float(input('x :'))
if x<0:
    print(-x)
elif x%2==0:
    print(1)
elif x%2==1:
    print(-1)
# Out:
# x :4
# 1

# %%
#if 28
N = int(input('Yil kiriting :'))
Y=N%100
Z=N%10
if Y!=0 and Z%4==0:
     print("Berilgan",N,"yil = Kabisa yili")
else:
     print("Berilgan",N,"yil = Kabisa yili emas")
# Out:
# Yil kiriting :2016
# Berilgan 2016 yil = Kabisa yili emas

# %%
#if 29
x = int(input("x :"))
if x>0 and x%2==0:
    print("musbat juft")
elif x>0 and x%2==1:
    print("musbat toq")
elif x<0 and x%2==0:
    print("manfiy juft")
elif x<0 and x%2==1:
    print("manfiy toq")
else:
    print("Son nolga teng")

# %%
#if 30
a = int(input("a son <1-999> : "))

if a>0 and a<9:
    if a%2==0:
        print('Bir xonali juft son')
    else:
        print('Bir xonali toq son')
elif a>0 and  a<99:
    if a%2==0:
        print('Ikki xonali juft son')
    else:
        print('Ikki xonali toq son')
elif a>0 and  a<999:
    if a%2==0:
        print('Uch xonali juft son')
    else:
        print('Uch xonali toq son')
elif a>0 and  a>999:
    print('Uch xonali sonda katta kiritdingiz')
else:
    print('Xato !!!')
# Out:
# a (1-999) = 13
# Ikki xonali toq son
