# %%
#Begin 1
a=int(input('a = '))
p=4*a
print('Perimetr',p)
# Out:
# a = 4
# Perimetr 16

# %%
#Begin 2
a = int(input('a = '))
S = a*a
print(S)

# %%
#Begin 3
a = int(input("a = "))
b = int(input("b = "))
S = a*b
P = 2*(a+b)
print("To'rtburchakning yuzi: ", S, "To'rtburchakning peremetiri: ", P)
# Out:
# a = 3
# b = 2
# To'rtburchakning yuzi:  6 To'rtburchakning peremetiri:  10

# %%
#Begin 4
d = int(input("d = "))
pi = 3.14
L = pi * d
print("Aylana uzunligi : ", L)

# %%
#Begin 5
a = int(input("a = "))
V = a*a*a
S = 6*(a**2)
print("Hajm: ", V, "Sirt: ", S)

# %%
#Begin 6
a = int(input("a = "))
b = int(input("b = "))
c = int(input("c = "))
V = a*b*c
S = 2*(a*b+b*c+a*c)
print("Hajm: ", V, "Sirt: ", S)

# %%
#Begin 7
R = int(input("R = "))
pi = 3.14
L = 2*pi*R
S = pi*R**2
print("Uzunligi: ", L, "Yuzasi: ", S)

# %%
#Begin 8
a = int(input("a = "))
b = int(input("b = "))
arif = (a+b)/2
print("O'rta arifmetik: ", arif)

# %%
#Begin 9
a = int(input("a = "))
b = int(input("b = "))
geo = (a*b)**(1/2)
print("O'rta geometrik: ", geo)

# %%
#Begin 10
a = int(input("a = "))
b = int(input("b = "))
print("Yig'indi: ", a+b, " Ko'aytma: ", a*b, " Kvadrat a+b: ",(a+b)**2, " Kavdrat a*b: ", (a*b)**2)

# %%
#Begin 11
a = int(input("a = "))
b = int(input("b = "))
print("Yig'indi: ", a+b, " Ko'aytma: ", a*b, " Modul |a + b|: ",abs(a+b), " Modul |a * b|: ", abs(a*b))

# %%
#Begin 12
a = int(input("a = "))
b = int(input("b = "))
c = (a**2+b**2)**(1/2)
P = a+b+c
print("Gipatenuza : ", c, " Peremetiri : ", P)

# %%
#Begin 13
R1 = int(input("R1 = "))
R2 = int(input("R2 = "))
pi = 3.14
S1 = pi*R1
S2 = pi*R2
S3 = pi*(R1-R2)
print("S1 = ", S1, " S2 = ", S2, " S3", S3)

# %%
#Begin 14
L=int(input("L = "))
pi = 3.14
R = L/(2*pi)
S = pi*R**2
print("Radius: ", R, " Yuzi: ", S)

# %%
#Begin 15
S = int(input("S = "))
pi = 3.14
R = (S/pi)**(1/2)
D = 2*R
L = 2*pi*R
print("Radius: ", R, " Diametr: ", D, " Uzunligi: ", L)

# %%
#Begin 16
x1 = int(input("X1 = "))
x2 = int(input("X2 = "))
print("Masofa  |x2 - x1|: ", abs(x2-x1))

# %%
#Begin 17
A = int(input("A = "))
B = int(input("B = "))
C = int(input("C = "))
AC = abs(c-a)
BC = abs(c-b)
yigindi = AC + BC
print("AC kesma: ", AC, " BC kesma: ", BC, " Yig'indi: ", yigindi)

# %%
#Begin 18
A = int(input("A = "))
B = int(input("B = "))
C = int(input("C = "))
AC = abs(c-a)
BC = abs(b-c)
k = AC*BC
print("Ko'paytma : ", k)

# %%
#Begin 19
ax = int(input("Ax = ")) 
ay = int(input("Ay = ")) 
cx = int(input("Cx = "))
cy = int(input("Cy = "))
bx = ax
by = cy
dx = cx
dy = ay
a = abs(ay - by)
b = abs(cx - bx)
P = 2*(a+b)
S = a*b
print("Peremetr: ", P, " Yuzi: ", S)

# %%
#Begin 20
x1 = int(input("x1 = "))
y1 = int(input("y1 = "))
x2 = int(input("x2 = "))
y2 = int(input("y2 = "))
m = ((x2-x1)**2 + (y2-y1)**2)**(1/2)
print("Masofa: ", m)

# %%
#Begin 21
x1 = int(input("X1 = "))
y1 = int(input("Y1 = "))
x2 = int(input("X2 = "))
y2 = int(input("Y2 = "))
x3 = int(input("X3 = "))
y3 = int(input("Y3 = "))
a = ((x2-x1)**2 + (y2-y1)**2)**(1/2)
b = ((x3-x1)**2 + (y3-y1)**2)**(1/2)
c = ((x3-x2)**2 + (y3-y2)**2)**(1/2)
p = (a+b+c)/2
S = (p*(p-a)*(p-b)*(p-c))**(1/2)
print("Peremetiri: ", p, " Yuzasi: ", S)

# %%
#Begin 22
a = int(input("A = ")) 
b = int(input("B = ")) 
a = a+b
b = a-b
a = a-b
print("A = ", a, " B = ", b)

# %%
#Begin 23
a = int(input("A = ")) 
b = int(input("B = "))
c = int(input("C = "))
print(a,b,c)
a, b, c = b, c, a
print(a, b,c)
# Out:
# A = 1
# B = 2
# C = 3
# 1 2 3
# 2 3 1

# %%
#Begin 24
a = int(input("A = ")) 
b = int(input("B = "))
c = int(input("C = "))
a = a+b+c
b = a-b-c
c = a-b-c
a = a-b-c
print(a,b,c)

# %%
#Begin 25 
x = float(input("X = "))
y = 3*(x**6)-6*(x**2)-7
print(y)

# %%
#Begin 26
x = float(input("x = "))
y = 4 * ((x - 3) ** 6) - 7 * ((x - 3) ** 3) + 2
print("x = ", y)

# %%
#Begin 27
a = int(input("a = "))
a_2 = a**2
a_4 = a**4
a_8 = a**8
print(a_2, a_4, a_8)
# Out:
# a = 2
# 4 16 256

# %%
#Begin 28
a = int(input("a = "))
a_2 = a**2
a_3 = a**3
a_5 = a**5
a_10 = a**10
a_15 = a**15
print(a_2,a_3,a_5, a_10,a_15)

# %%
#Begin 29
a = float(input("Burchakni kiriting: "))
pi = 3.14
R = (a*pi)/180
print(R, " Radian")

# %%
#Begin 30
pi = 3.14
alfa = float(input("Radian kiriting: "))
gradius = (alfa*180)/pi
print(gradius," gradius")

# %%
#Begin 31
TF = int(input("Farengeyt: "))
TC = (TF-32)*(5/9)
print( TC," gradius")

# %%
#Begin 32
TC = float(input("Gradius: "))
TF = TC*(9/5)+32
print(TF," Farengeyt")

# %%
#Begin 33
X = int(input("Konfet massasi: "))
A = int(input("X kg konfet narxi:"))
Y = int(input("Y kg konfet massasi: "))
kg1 = A/X
y = (A*Y)/X
print("1 kg konfet narxi: ", kg1, "\n", Y, "kg konfet narxi: ", y)

# %%
#Begin 34
X = int(input("Shokolad massasi: "))
A = int(input("X kg shokalad narxi:"))
Y = int(input("Konfet massasi: "))
B = int(input("Y kg konfet narxi:"))
i = A/X
j = B/Y
delta = i - j
print("1 kg shokalad 1kg konfetdan ", farq, "so'm qimmat")

# %%
#Begin 35
v = int(input("Qayiqning tezligi: "))
u = int(input("Daryoning tezligi: "))
t1 = int(input("Daryo bo'ylab harakatlanish vaqti: "))
t2 = int(input("Daryoga qarshi harakatlanish vaqti: "))
oqim_boylab = (v+u)*t1
oqimga_qarshi = (v-u)*t2
S = oqim_boylab + oqimga_qarshi
print("Bosib o'tgan masofa: ", S, " km")

# %%
#Begin 36
v1 = int(input("Birinchi avtomobil tezligi: "))
v2 = int(input("Ikkinchi avtomobil tezligi: "))
S = int(input("Ular orasidagi masofa: "))
t = int(input("Harakat vaqti: "))
S1 = v1*t
S2 = v2*t
masofa = S+S1+S2
print("Orasidagi masofa: ", masofa, " km")

# %%
#Begin 37
v1 = int(input("Birinchi avtomobil tezligi: "))
v2 = int(input("Ikkinchi avtomobil tezligi: "))
S = int(input("Ular orasidagi masofa: "))
t = int(input("Harakat vaqti: "))
S1 = v1*t
S2 = v2*t
delta = abs(S-S1-S2)
print("Orasidagi masofa: ", delta, " km")

# %%
#Begin 38
A = int(input("A koifisent: "))
B = int(input("B koifisent: "))
x = (-B)/A
print("x =  ", x)

# %%
#Begin 39
A = int(input("A koifisent: "))
B = int(input("B koifisent: "))
C = int(input("C koifisent: "))
D = B**2-4*A*C
x1 = (-B -(D) * (1/2))
x2 = (-B + (D) * (1/2))
print("x1 = ", x1, " x2 = ", x2)

# %%
#Begin 40
A1 = int(input("A1 koifisent: "))
B1 = int(input("B1 koifisent: "))
C1 = int(input("C1 koifisent: "))
A2 = int(input("A2 koifisent: "))
B2 = int(input("B2 koifisent: "))
C2 = int(input("C2 koifisent: "))
D = A1*B2 - A2*B1
x = (C1*B2-C2*B1)/D
y = (A1*C2 - A2*C1)/D
print("x = ", x, " y = ", y)
