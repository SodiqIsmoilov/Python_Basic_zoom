# %%
#while 7
n = int(input('n soni : '))
k=0
while n>=k**2:    
    k+=1
print(k)
# Out:
# n soni:50
# 8

# %%
#while 8
n = int(input('n soni : '))
k=0
while k**2 <= n:    
    k+=1
print(k-1)
# Out:
# n soni : 50
# 7

# %%
#while 9    n>1
n = int(input('n soni : '))
k=0
while n>=3**k:    
    k+=1
print(k)
# Out:
# n soni : 100
# 5

# %%
#while 10
n = int(input('n soni : '))
k=0
while n>=3**k:    
    k+=1
print(k-1)
# Out:
# n soni : 100
# 4

# %%
#while 11
n = int(input('n soni : '))
k = 1
s = 0
while s<=n:
    s+=k
    k+=1
print(k, 'summa', s)
# Out:
# n soni : 55
# 12 summa 66

# %%
#while 12
n = int(input('n soni : '))
k = 1
s = 0
while n>=s+k:
    s+=k
    k+=1
print(k, 'summa', s)
# Out:
# n soni : 55
# 11 summa 55

# %%
#while 13
n = int(input('n soni : '))
k = 1
s = 0
while n>=s+1/k:
    s+=1/k
    k+=1    
print(k-1, 'summa ', s)
# Out:
# n soni : 2
# 3 summa  1.8333333333333333

# %%
#while 14
n = int(input('n soni : '))
k = 1
s = 0
while n>=s:
    s+=1/k
    k+=1 
print(k-1, 'summa ', s)
# Out:
# n soni : 3
# 11 summa  3.0198773448773446
