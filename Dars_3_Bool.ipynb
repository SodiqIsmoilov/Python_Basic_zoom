# %%
#Bool 1
A = int(input("A = "))
print(A > 0)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [1], in <module>
# ----> 1 A = int(input("A = "))
#       2 print(A > 0)
#
# File C:\Python310\lib\site-packages\ipykernel\kernelbase.py:1044, in Kernel.raw_input(self, prompt)
#    1040 if not self._allow_stdin:
#    1041     raise StdinNotImplementedError(
#    1042         "raw_input was called, but this frontend does not support input requests."
#    1043     )
# -> 1044 return self._input_request(
#    1045     str(prompt),
#    1046     self._parent_ident["shell"],
#    1047     self.get_parent("shell"),
#    1048     password=False,
#    1049 )
#
# File C:\Python310\lib\site-packages\ipykernel\kernelbase.py:1089, in Kernel._input_request(self, prompt, ident, parent, password)
#    1086             break
#    1087 except KeyboardInterrupt:
#    1088     # re-raise KeyboardInterrupt, to truncate traceback
# -> 1089     raise KeyboardInterrupt("Interrupted by user") from None
#    1090 except Exception:
#    1091     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
# A = 3

# %%
#Bool 2
A = int(input("A = "))
print(A%2 == 1)

# %%
#Bool 3
A = int(input("A = "))
print(A%2 == 0)

# %%
#Bool 4
A = int(input("A = "))
B = int(input("B = "))
print( A>2 and B<=3 )

# %%
#Bool 5
A = int(input("A = "))
B = int(input("B = "))
print(A>=0 or B<-2)

# %%
#Bool 6
A = int(input("A = "))
B = int(input("B = "))
C = int(input("C = "))
print(A<=B and B<=C)
print( A<=B<=C )
# Out:
# A = 1
# B = 2
# C = 3
# True
# True

# %%
#Bool 7
A = int(input("A = "))
B = int(input("B = "))
C = int(input("C = "))
print(A<B and B<C)
print(A<B<C)

# %%
#Bool 8
A = int(input("A = "))
B = int(input("B = "))
print(A%2 == 1 and B%2 == 1)
#print(A%2 and B%2)
# Out:
# A = 3
# B = 5
# True
# 1

# %%
#Bool 9
A = int(input("A = "))
B = int(input("B = "))
print(A%2 == 1 or B%2 == 1)

# %%
#Bool 10
A = int(input("A = "))
B = int(input("B = "))
print((A%2 == 1 and B%2 == 0) or (A%2 == 0 and B%2 == 1))

# %%
#Bool 11
A = int(input("A = "))
B = int(input("B = "))
print((A%2 == 1 and B%2 == 1) or (A%2 == 0 and B%2 == 0))

# %%
#Bool 12
A = int(input("A = "))
B = int(input("B = "))
C = int(input("C = "))
print(A>0 and B>0 and C>0)

# %%
#Bool 13
A = int(input("A = "))
B = int(input("B = "))
C = int(input("C = "))
print(A>0 or B>0 or C>0)

# %%
#Bool 14
A = int(input("A = "))
B = int(input("B = "))
C = int(input("C = "))
print( 
    (A>0 and B<0 and C<0) or 
    (B>0 and A<0 and C<0) or 
    (C>0 and A<0 and B<0) )

# %%
#Bool 15
A = int(input("A = "))
B = int(input("B = "))
C = int(input("C = "))
print( 
    (A>0 and B>0 and C<0) or 
    (B>0 and C>0 and A<0) or 
    (C>0 and A>0 and B<0) )

# %%
#Bool 16
A = int(input("Ikki xonali son: "))
print( 9<A<99 and A%2 == 0 )
# Out:
# Ikki xonali son: 11
# False

# %%
#Bool 17
A = int(input("Uch xonali son: "))
print(99<A<999 and A%2 == 1)
# Out:
# Uch xonali son: 101
# True

# %%
#Bool 18
A = int(input("A = "))
B = int(input("B = "))
C = int(input("C = "))
print(A==B or B==C or A==C)

# %%
#Bool 19
A = int(input("A = "))
B = int(input("B = "))
C = int(input("C = "))
print(A==-B or B==-C or A==-C)

# %%
#Bool 20
A = int(input("Uch xonali son: "))
yuz = A // 100
on = A % 100 // 10
bir = A % 10
print(yuz!=on and on!=bir and yuz!=bir)
# Out:
# Uch xonali son: 112
# False

# %%
#Bool 21
A = int(input("Uch xonali son: "))
yuz = A // 100
on = A % 100 // 10
bir = A % 10
print(yuz<on<bir)

# %%
#Bool 22
A = int(input("Uch xonali son: "))
yuz = A // 100
on = A % 100 // 10
bir = A % 10
print(yuz<on<bir or yuz>on>bir)

# %%
#Bool23
a = int(input("Uch xonali son: "))
y = a // 100
b = a % 10
print(y == b)

# %%
#Bool 24
A = int(input("A(A!=0) = "))
B = int(input("B = "))
C = int(input("C = "))
D = B**2-4*A*C
print(D>=0)

# %%
#Bool 25
x = int(input("x = "))
y = int(input("y = "))
print(x<0 and y>0)

# %%
#Bool 26
x = int(input("x = "))
y = int(input("y = "))
print(x>0 and y<0)

# %%
#Bool 27
x = int(input("x = "))
y = int(input("y = "))
print((x<0 and y>0) or (x<0 and y<0))

# %%
#Bool 28
x = int(input("x = "))
y = int(input("y = "))
print((x>0 and y>0) or (x<0 and y<0))

# %%
#Bool 29
x = int(input("x = "))
y = int(input("y = "))
x1 = int(input("x1 = "))
y1 = int(input("y1 = "))
x2 = int(input("x2 = "))
y2 = int(input("y2 = "))
print(x1<x<x2 and y1<y<y2)
# Out:
# x = 0
# y = 0
# x1 = -1
# y1 = 5
# x2 = 1
# y2 = 2
# False

# %%
#Bool 30
a = int(input("a = "))
b = int(input("b = "))
c = int(input("c = "))
print(a == b == c)

# %%
#Bool 31
a = int(input("a = "))
b = int(input("b = "))
c = int(input("c = "))
print(a == b!=c or a == c!=b or b == c!=a)

# %%
#Bool 32
a = int(input("a = "))
b = int(input("b = "))
c = int(input("c = "))
print(a**2+b**2 == c**2 or b**2+c**2 == a**2 or a**2+c**2 == b**2)

# %%
#Bool 33
a = int(input("a = "))
b = int(input("b = "))
c = int(input("c = "))
print(a+b>c and a+c>b and b+c>a)
# Out:
# a = 3
# b = 4
# c = 5
# True

# %%
#Bool 34
x = int(input("x <1-8> = "))
y = int(input("y <1-8> = "))
print((x+y)%2 ==1)
# Out:
# x <1-8> = 8
# y <1-8> = 3
# True

# %%
#Bool 35
x1 = int(input("x1 <1-8> = "))
y1 = int(input("y1 <1-8> = "))
x2 = int(input("x2 <1-8> = "))
y2 = int(input("y2 <1-8> = "))
print( (x1+y1)%2==1 and (x2+y2)%2==1 )
# Out:
# x1 <1-8> = 6
# y1 <1-8> = 5
# x2 <1-8> = 3
# y2 <1-8> = 5
# False

# %%
#Bool 36
x1 = int(input("x1 <1-8> = "))
y1 = int(input("y1 <1-8> = "))
x2 = int(input("x2 <1-8> = "))
y2 = int(input("y2 <1-8> = "))
print(x1 == x2 or y1 == y2)

# %%
#Bool 37
x1 = int(input("x1 <1-8> = "))
y1 = int(input("y1 <1-8> = "))
x2 = int(input("x2 <1-8> = "))
y2 = int(input("y2 <1-8> = "))
print(x2-1<=x1<=x2+1 and y2-1<=y2<=y1+1)

# %%
#Bool 38
x1 = int(input("x1 <1-8> = "))
y1 = int(input("y1 <1-8> = "))
x2 = int(input("x2 <1-8> = "))
y2 = int(input("y2 <1-8> = "))
print( (x1-x2)**2 + (y1-y2)**2 ==5)
# Out:
# x1 <1-8> = 3
# y1 <1-8> = 5
# x2 <1-8> = 4
# y2 <1-8> = 3
# True

# %%
#Bool 39
x1 = int(input("x1 <1-8> = "))
y1 = int(input("y1 <1-8> = "))
x2 = int(input("x2 <1-8> = "))
y2 = int(input("y2 <1-8> = "))
print(abs(x1-x2)>8 and y1==y2 or
      abs(y1-y2)>8 and x1==x2 or
      abs(x1-x2)==1 and abs(y1-y2)==1)

# %%
#Bool 40
y1 = int(input("y1="))
x2 = int(input("x2="))
y2 = int(input("y2="))
print(x1==x2 or y1==y2 or abs(x1-x2)==abs(y1-y2))

# %%
# Qo'shimcha
A = int(input("A = "))
B = int(input("B = "))
C = int(input("C = "))
print((A%2==1 and B%2==0 and C%2==0) or 
      (A%2==0 and B%2==1 and C%2==0) or 
      (A%2==0 and B%2==0 and C%2==1))

# %%
A = int(input("A = "))
B = int(input("B = "))
C = int(input("C = "))
print(A>0 and B>0 and C>0)

# %%
a = int(input("a = "))
b = int(input("b = "))
c = int(input("c = "))
print(a+b > c and a+c>b and b+c>a)

# %%
a = int(input("a = "))
if a>0:
    print("Musbat")
elif a<0:
    print("Manfiy")
else:
    print("nol")

# %%
x1 = int(input("x1="))
y1 = int(input("y1="))
x2 = int(input("x2="))
y2 = int(input("y2="))
print(abs(x1-x2)==2**abs(y1-y2)
      or 2**abs(x1-x2)==abs(y1-y1))
